# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv('/workspaces/Python/Practica 5 csvs/states.csv')
plt.figure(figsize = (8,6))
sb.heatmap(df.isnull(), cbar=False , cmap = 'magma')
# Out:
# <Axes: >

# %%
print(df.shape)
df_dropped_any = df.dropna(how = 'any')
df_dropped_any
# Out:
# (5084, 9)
#         id                             name  country_id country_code  \
# 170   3656                     Buenos Aires          11           AR
# 171   3647                        Catamarca          11           AR
# 172   3640                            Chaco          11           AR
# 173   3651                           Chubut          11           AR
# 174   4880  Ciudad Autónoma de Buenos Aires          11           AR
# ...    ...                              ...         ...          ...
# 4975  2041                          Yaracuy         239           VE
# 4976  2042                            Zulia         239           VE
# 5040  5074                      Saint Croix         242           VI
# 5041  5073                       Saint John         242           VI
# 5042  5072                     Saint Thomas         242           VI
#
#              country_name state_code      type   latitude  longitude
# ...

# %%
print(df.shape)
df_dropped_all = df.dropna(how = 'all')
df_dropped_all
# Out:
# (5084, 9)
#         id                         name  country_id country_code country_name  \
# 0     3901                   Badakhshan           1           AF  Afghanistan
# 1     3871                      Badghis           1           AF  Afghanistan
# 2     3875                      Baghlan           1           AF  Afghanistan
# 3     3884                        Balkh           1           AF  Afghanistan
# 4     3872                       Bamyan           1           AF  Afghanistan
# ...    ...                          ...         ...          ...          ...
# 5079  1953    Mashonaland West Province         247           ZW     Zimbabwe
# 5080  1960            Masvingo Province         247           ZW     Zimbabwe
# 5081  1954  Matabeleland North Province         247           ZW     Zimbabwe
# 5082  1952  Matabeleland South Province         247           ZW     Zimbabwe
# 5083  1957            Midlands Province         247           ZW     Zimbabwe
#
# ...

# %%
print(df.shape)
df_dropped_d =df.dropna(thresh=2)
df_dropped_d
# Out:
# (5084, 9)
#         id                         name  country_id country_code country_name  \
# 0     3901                   Badakhshan           1           AF  Afghanistan
# 1     3871                      Badghis           1           AF  Afghanistan
# 2     3875                      Baghlan           1           AF  Afghanistan
# 3     3884                        Balkh           1           AF  Afghanistan
# 4     3872                       Bamyan           1           AF  Afghanistan
# ...    ...                          ...         ...          ...          ...
# 5079  1953    Mashonaland West Province         247           ZW     Zimbabwe
# 5080  1960            Masvingo Province         247           ZW     Zimbabwe
# 5081  1954  Matabeleland North Province         247           ZW     Zimbabwe
# 5082  1952  Matabeleland South Province         247           ZW     Zimbabwe
# 5083  1957            Midlands Province         247           ZW     Zimbabwe
#
# ...

# %%
print(df.shape)
df_2=df.dropna(subset=['latitude'])
df_2
# Out:
# (5084, 9)
#         id                         name  country_id country_code country_name  \
# 0     3901                   Badakhshan           1           AF  Afghanistan
# 1     3871                      Badghis           1           AF  Afghanistan
# 2     3875                      Baghlan           1           AF  Afghanistan
# 3     3884                        Balkh           1           AF  Afghanistan
# 4     3872                       Bamyan           1           AF  Afghanistan
# ...    ...                          ...         ...          ...          ...
# 5079  1953    Mashonaland West Province         247           ZW     Zimbabwe
# 5080  1960            Masvingo Province         247           ZW     Zimbabwe
# 5081  1954  Matabeleland North Province         247           ZW     Zimbabwe
# 5082  1952  Matabeleland South Province         247           ZW     Zimbabwe
# 5083  1957            Midlands Province         247           ZW     Zimbabwe
#
# ...

# %%
from scipy import stats
print(df_dropped_any.shape)
df_new = df_dropped_any[(np.abs(stats.zscore(df_dropped_any.latitude)) < 3)]
df_new
# Out:
# (1587, 9)
#         id          name  country_id country_code         country_name  \
# 171   3647     Catamarca          11           AR            Argentina
# 172   3640         Chaco          11           AR            Argentina
# 175   3642       Córdoba          11           AR            Argentina
# 176   3638    Corrientes          11           AR            Argentina
# 177   3654    Entre Ríos          11           AR            Argentina
# ...    ...           ...         ...          ...                  ...
# 4975  2041       Yaracuy         239           VE            Venezuela
# 4976  2042         Zulia         239           VE            Venezuela
# 5040  5074   Saint Croix         242           VI  Virgin Islands (US)
# 5041  5073    Saint John         242           VI  Virgin Islands (US)
# 5042  5072  Saint Thomas         242           VI  Virgin Islands (US)
#
#      state_code      type   latitude  longitude
# 171           K  province -28.471588 -65.787721
# ...
